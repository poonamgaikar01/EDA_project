# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import datetime

# %%
df1=pd.read_csv("/Users/vinlok/github_personal/poonamgaikar01/EDA_project/turnstile_210515.txt")
df2=pd.read_csv("/Users/vinlok/github_personal/poonamgaikar01/EDA_project/turnstile_210522.txt")
df3=pd.read_csv("/Users/vinlok/github_personal/poonamgaikar01/EDA_project/turnstile_210529.txt")
df4=pd.read_csv("/Users/vinlok/github_personal/poonamgaikar01/EDA_project/turnstile_210605.txt")
df5=pd.read_csv("/Users/vinlok/github_personal/poonamgaikar01/EDA_project/turnstile_210612.txt")
df6=pd.read_csv("/Users/vinlok/github_personal/poonamgaikar01/EDA_project/turnstile_210619.txt")
df7=pd.read_csv("/Users/vinlok/github_personal/poonamgaikar01/EDA_project/turnstile_210626.txt")
df8=pd.read_csv("/Users/vinlok/github_personal/poonamgaikar01/EDA_project/turnstile_210703.txt")
df9=pd.read_csv("/Users/vinlok/github_personal/poonamgaikar01/EDA_project/turnstile_210710.txt")
df10=pd.read_csv("/Users/vinlok/github_personal/poonamgaikar01/EDA_project/turnstile_210717.txt")
df11=pd.read_csv("/Users/vinlok/github_personal/poonamgaikar01/EDA_project/turnstile_210724.txt")
df12=pd.read_csv("/Users/vinlok/github_personal/poonamgaikar01/EDA_project/turnstile_210731.txt")

df = pd.concat([df1,df2,df3,df4,df5,df6,df7,df8,df9,df10,df11,df12])

# %%
df.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/08/2021  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/08/2021  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/08/2021  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/08/2021  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/08/2021  16:00:00
#
#       DESC  ENTRIES  \
# 0  REGULAR  7568196
# 1  REGULAR  7568207
# 2  REGULAR  7568213
# 3  REGULAR  7568245
# 4  REGULAR  7568357
#
#    EXITS
# 0                                            2585862
# 1                                            2585868
# 2                                            2585880
# 3                                            2585920
# 4                                            2585940

# %%
# df.sort_values(by=['DATE','TIME']) #checking start/end of date/time

# %%
df.columns = df.columns.str.replace(' ', '')

# %%
# df['TIME']=pd.to_datetime(df['TIME'],format='%H:%M:%S')

# %%
df.dtypes
# Out:
# C/A         object
# UNIT        object
# SCP         object
# STATION     object
# LINENAME    object
# DIVISION    object
# DATE        object
# TIME        object
# DESC        object
# ENTRIES      int64
# EXITS        int64
# dtype: object

# %%
df['DATE_TIME']=df.DATE + " " + df.TIME

# %%
station_mask = (
                (df["STATION"] == "ATLANTIC AV") |
                (df["STATION"] == "FLATBUSH AV-B.C")|
                (df["STATION"] == "ATL AV-BARCLAY")|
                (df["STATION"] == "25 AV")|
                (df["STATION"] == "BERGEN ST")|
                (df["STATION"] == "FULTON ST")|
                (df["STATION"] == "LAFAYETTE AV")
               )
station_mask
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 209458    False
# 209459    False
# 209460    False
# 209461    False
# 209462    False
# Name: STATION, Length: 2512647, dtype: bool

# %%
df.dtypes
# Out:
# C/A          object
# UNIT         object
# SCP          object
# STATION      object
# LINENAME     object
# DIVISION     object
# DATE         object
# TIME         object
# DESC         object
# ENTRIES       int64
# EXITS         int64
# DATE_TIME    object
# dtype: object

# %%
df.DATE_TIME=pd.to_datetime(df['DATE_TIME'])

# %%
df.dtypes
# Out:
# C/A                  object
# UNIT                 object
# SCP                  object
# STATION              object
# LINENAME             object
# DIVISION             object
# DATE                 object
# TIME                 object
# DESC                 object
# ENTRIES               int64
# EXITS                 int64
# DATE_TIME    datetime64[ns]
# dtype: object

# %%
df.head()
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/08/2021  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/08/2021  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/08/2021  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/08/2021  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/08/2021  16:00:00
#
#       DESC  ENTRIES    EXITS           DATE_TIME
# 0  REGULAR  7568196  2585862 2021-05-08 00:00:00
# 1  REGULAR  7568207  2585868 2021-05-08 04:00:00
# 2  REGULAR  7568213  2585880 2021-05-08 08:00:00
# 3  REGULAR  7568245  2585920 2021-05-08 12:00:00
# 4  REGULAR  7568357  2585940 2021-05-08 16:00:00

# %%
selected_stations=df[station_mask]
selected_stations
# Out:
#          C/A  UNIT       SCP          STATION  LINENAME DIVISION        DATE  \
# 12547   A077  R028  03-00-00        FULTON ST  ACJZ2345      BMT  05/08/2021
# 12548   A077  R028  03-00-00        FULTON ST  ACJZ2345      BMT  05/08/2021
# 12549   A077  R028  03-00-00        FULTON ST  ACJZ2345      BMT  05/08/2021
# 12550   A077  R028  03-00-00        FULTON ST  ACJZ2345      BMT  05/08/2021
# 12551   A077  R028  03-00-00        FULTON ST  ACJZ2345      BMT  05/08/2021
# ...      ...   ...       ...              ...       ...      ...         ...
# 206770  R647  R110  02-06-00  FLATBUSH AV-B.C        25      IRT  07/30/2021
# 206771  R647  R110  02-06-00  FLATBUSH AV-B.C        25      IRT  07/30/2021
# 206772  R647  R110  02-06-00  FLATBUSH AV-B.C        25      IRT  07/30/2021
# 206773  R647  R110  02-06-00  FLATBUSH AV-B.C        25      IRT  07/30/2021
# 206774  R647  R110  02-06-00  FLATBUSH AV-B.C        25      IRT  07/30/2021
#
# ...

# %%
selected_stations_data=selected_stations.drop(columns=['LINENAME','DIVISION','DESC'])

# %%
selected_stations_data.head(50)
# Out:
#         C/A  UNIT       SCP    STATION        DATE                TIME  \
# 12547  A077  R028  03-00-00  FULTON ST  05/08/2021 1900-01-01 03:00:00
# 12548  A077  R028  03-00-00  FULTON ST  05/08/2021 1900-01-01 07:00:00
# 12549  A077  R028  03-00-00  FULTON ST  05/08/2021 1900-01-01 11:00:00
# 12550  A077  R028  03-00-00  FULTON ST  05/08/2021 1900-01-01 15:00:00
# 12551  A077  R028  03-00-00  FULTON ST  05/08/2021 1900-01-01 19:00:00
# 12552  A077  R028  03-00-00  FULTON ST  05/08/2021 1900-01-01 23:00:00
# 12553  A077  R028  03-00-00  FULTON ST  05/09/2021 1900-01-01 03:00:00
# 12554  A077  R028  03-00-00  FULTON ST  05/09/2021 1900-01-01 07:00:00
# 12555  A077  R028  03-00-00  FULTON ST  05/09/2021 1900-01-01 11:00:00
# 12556  A077  R028  03-00-00  FULTON ST  05/09/2021 1900-01-01 15:00:00
# 12557  A077  R028  03-00-00  FULTON ST  05/09/2021 1900-01-01 19:00:00
# 12558  A077  R028  03-00-00  FULTON ST  05/09/2021 1900-01-01 23:00:00
# ...

# %%
Entries_byDate = selected_stations_data.groupby(['STATION','DATE']).ENTRIES.agg({'min_ENTRIES':'min'})
Entries_byDate = Entries_byDate.reset_index()
Entries_byDate['DAILY_ENTRIES'] = Entries_byDate.groupby(['STATION','DATE']).min_Entries.diff().shift(-1)

# %%
Entries_byDate.loc[Entries_byDate['DAILY_ENTRIES'] <= 0, 'DAILY_ENTRIES'] = np.nan
Entries_byDate.loc[Entries_byDate['DAILY_ENTRIES'] > 100000, 'DAILY_ENTRIES'] = np.nan
Entries_byDate.head()
